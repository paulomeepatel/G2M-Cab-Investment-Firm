# %%
#Importing necessery libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#importing data

cab_data = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\Data Glacier Internship\G2M Cab Investment Firm\Cab_Data.csv")
transactionID_data = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\Data Glacier Internship\G2M Cab Investment Firm\Transaction_ID.csv")
customer_ID = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\Data Glacier Internship\G2M Cab Investment Firm\Customer_ID.csv")
city_data = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\Data Glacier Internship\G2M Cab Investment Firm\City.csv")

# %%
cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     08/01/2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     06/01/2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     02/01/2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     07/01/2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     03/01/2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB

# %%
cab_data.shape
# Out:
# (359392, 7)

# %%
transactionID_data.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
transactionID_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
transactionID_data.shape
# Out:
# (440098, 3)

# %%
customer_ID.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
customer_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_ID.shape
# Out:
# (49171, 4)

# %%
city_data.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city_data.shape
# Out:
# (20, 3)

# %%
cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
transactionID_data.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
customer_ID.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
city_data.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
#converting datatype of dates

cab_data['Date of Travel'] = pd.to_datetime(cab_data['Date of Travel'])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
#seperating months and years

months = []
years = []
for i in range(len(cab_data['Date of Travel'])):
    months.append(cab_data['Date of Travel'][i].month)
    years.append(cab_data['Date of Travel'][i].year)
cab_data['Month'] = months
cab_data['Year'] = years

# %%
cab_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-08-01    Pink Cab     ATLANTA GA
# 1             10000012     2016-06-01    Pink Cab     ATLANTA GA
# 2             10000013     2016-02-01    Pink Cab     ATLANTA GA
# 3             10000014     2016-07-01    Pink Cab     ATLANTA GA
# 4             10000015     2016-03-01    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-08-01  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-04-01  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-05-01  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-05-01  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-02-01  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Month  Year
# 0              30.45         370.95      313.6350      8  2016
# ...

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  datetime64[ns]
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
#  7   Month           359392 non-null  int64
#  8   Year            359392 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(2)
# memory usage: 24.7+ MB

# %%
#consolidating into master dataframe

master_data = cab_data.merge(transactionID_data, on = 'Transaction ID').merge(customer_ID, on = 'Customer ID').merge(city_data, on = 'City')

# %%
master_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-08-01    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-06-01    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-06-07  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-02-08  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Month  Year  Customer ID  \
# 0              30.45         370.95      313.6350      8  2016        29290
# ...

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Month               359392 non-null  int64
#  8   Year                359392 non-null  int64
#  9   Customer ID         359392 non-null  int64
#  10  Payment_Mode        359392 non-null  object
#  11  Gender              359392 non-null  object
#  12  Age                 359392 non-null  int64
#  13  Income (USD/Month)  359392 non-null  int64
#  14  Population          359392 non-null  object
# ...

# %%
master_data.isnull().sum()
# Out:
# Transaction ID        0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Month                 0
# Year                  0
# Customer ID           0
# Payment_Mode          0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Population            0
# Users                 0
# dtype: int64

# %%
for column in master_data.columns:
    if ' ' in column:
        master_data = master_data.rename(columns = {column:column.replace(' ', '_')})
        
for column in ['Population','Users']:
    master_data[column] = master_data[column].str.replace(',', '')

# %%
master_data
# Out:
#         Transaction_ID Date_of_Travel     Company           City  \
# 0             10000011     2016-08-01    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-06-01    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-06-07  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-02-08  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM_Travelled  Price_Charged  Cost_of_Trip  Month  Year  Customer_ID  \
# 0              30.45         370.95      313.6350      8  2016        29290
# ...

# %%
for column in ["Company", "City", "Payment_Mode", "Gender"]:
    master_data[column] = master_data[column].astype('category')

for column in ["Population", "Users"]:
    master_data[column] = master_data[column].astype('int64')

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction_ID      359392 non-null  int64
#  1   Date_of_Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  category
#  3   City                359392 non-null  category
#  4   KM_Travelled        359392 non-null  float64
#  5   Price_Charged       359392 non-null  float64
#  6   Cost_of_Trip        359392 non-null  float64
#  7   Month               359392 non-null  int64
#  8   Year                359392 non-null  int64
#  9   Customer_ID         359392 non-null  int64
#  10  Payment_Mode        359392 non-null  category
#  11  Gender              359392 non-null  category
#  12  Age                 359392 non-null  int64
#  13  Income_(USD/Month)  359392 non-null  int64
#  14  Population          359392 non-null  int64
# ...

# %%
#seperating both companies datasets

pink_cab = master_data [ master_data['Company'] == 'Pink Cab']
yellow_cab = master_data [ master_data['Company'] == 'Yellow Cab']

# %%
pink_cab
# Out:
#         Transaction_ID Date_of_Travel   Company           City  KM_Travelled  \
# 0             10000011     2016-08-01  Pink Cab     ATLANTA GA         30.45
# 3             10000012     2016-06-01  Pink Cab     ATLANTA GA         28.62
# 6             10395626     2018-10-27  Pink Cab     ATLANTA GA         13.39
# 7             10000013     2016-02-01  Pink Cab     ATLANTA GA          9.04
# 11            10000014     2016-07-01  Pink Cab     ATLANTA GA         33.17
# ...                ...            ...       ...            ...           ...
# 359332        10200082     2017-07-23  Pink Cab  WASHINGTON DC         20.23
# 359346        10262863     2017-11-19  Pink Cab  WASHINGTON DC          4.44
# 359356        10417014     2018-02-12  Pink Cab  WASHINGTON DC         40.95
# 359358        10197277     2017-07-23  Pink Cab  WASHINGTON DC         32.64
# 359363        10267182     2017-11-27  Pink Cab  WASHINGTON DC         21.40
#
# ...

# %%
#adding profit column

pink_cab['profit'] = pink_cab['Price_Charged'] - pink_cab['Cost_of_Trip']
pink_cab
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\3337464186.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pink_cab['profit'] = pink_cab['Price_Charged'] - pink_cab['Cost_of_Trip']
#         Transaction_ID Date_of_Travel   Company           City  KM_Travelled  \
# 0             10000011     2016-08-01  Pink Cab     ATLANTA GA         30.45
# 3             10000012     2016-06-01  Pink Cab     ATLANTA GA         28.62
# 6             10395626     2018-10-27  Pink Cab     ATLANTA GA         13.39
# 7             10000013     2016-02-01  Pink Cab     ATLANTA GA          9.04
# 11            10000014     2016-07-01  Pink Cab     ATLANTA GA         33.17
# ...                ...            ...       ...            ...           ...
# ...

# %%
pink_cab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84711 entries, 0 to 359363
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      84711 non-null  int64
#  1   Date_of_Travel      84711 non-null  datetime64[ns]
#  2   Company             84711 non-null  category
#  3   City                84711 non-null  category
#  4   KM_Travelled        84711 non-null  float64
#  5   Price_Charged       84711 non-null  float64
#  6   Cost_of_Trip        84711 non-null  float64
#  7   Month               84711 non-null  int64
#  8   Year                84711 non-null  int64
#  9   Customer_ID         84711 non-null  int64
#  10  Payment_Mode        84711 non-null  category
#  11  Gender              84711 non-null  category
#  12  Age                 84711 non-null  int64
#  13  Income_(USD/Month)  84711 non-null  int64
#  14  Population          84711 non-null  int64
# ...

# %%
yellow_cab
# Out:
#         Transaction_ID Date_of_Travel     Company           City  \
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# 5             10324737     2018-04-05  Yellow Cab     ATLANTA GA
# 8             10079404     2016-09-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-06-07  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-02-08  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM_Travelled  Price_Charged  Cost_of_Trip  Month  Year  Customer_ID  \
# 1              26.19         598.70      317.4228      7  2018        29290
# ...

# %%
#adding profit column

yellow_cab['profit'] = yellow_cab['Price_Charged'] - yellow_cab['Cost_of_Trip']
yellow_cab
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\2230521332.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yellow_cab['profit'] = yellow_cab['Price_Charged'] - yellow_cab['Cost_of_Trip']
#         Transaction_ID Date_of_Travel     Company           City  \
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# 5             10324737     2018-04-05  Yellow Cab     ATLANTA GA
# 8             10079404     2016-09-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# ...

# %%
yellow_cab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274681 entries, 1 to 359391
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction_ID      274681 non-null  int64
#  1   Date_of_Travel      274681 non-null  datetime64[ns]
#  2   Company             274681 non-null  category
#  3   City                274681 non-null  category
#  4   KM_Travelled        274681 non-null  float64
#  5   Price_Charged       274681 non-null  float64
#  6   Cost_of_Trip        274681 non-null  float64
#  7   Month               274681 non-null  int64
#  8   Year                274681 non-null  int64
#  9   Customer_ID         274681 non-null  int64
#  10  Payment_Mode        274681 non-null  category
#  11  Gender              274681 non-null  category
#  12  Age                 274681 non-null  int64
#  13  Income_(USD/Month)  274681 non-null  int64
#  14  Population          274681 non-null  int64
# ...

# %%
selected_columns = ['KM_Travelled', 'Price_Charged', 'Cost_of_Trip', 'Age', 'Income_(USD/Month)', 'Population', 'Users']
filtered_pink_cab = pink_cab[selected_columns]
filtered_yellow_cab = yellow_cab[selected_columns]

# %%
#statistics for pink cab

pink_cab_stats = filtered_pink_cab.describe()
pink_cab_stats
# Out:
#        KM_Travelled  Price_Charged  Cost_of_Trip           Age  \
# count  84711.000000   84711.000000  84711.000000  84711.000000
# mean      22.559917     310.800856    248.148682     35.322414
# std       12.231092     181.995661    135.403345     12.644780
# min        1.900000      15.600000     19.000000     18.000000
# 25%       12.000000     159.970000    131.868000     25.000000
# 50%       22.440000     298.060000    246.330000     33.000000
# 75%       32.960000     441.505000    360.180000     42.000000
# max       48.000000    1623.480000    576.000000     65.000000
#
#        Income_(USD/Month)    Population          Users
# count        84711.000000  8.471100e+04   84711.000000
# mean         15059.047137  2.350642e+06  125590.813330
# std           7991.077762  2.734890e+06   94593.433659
# min           2000.000000  2.489680e+05    3643.000000
# 25%           8371.000000  8.148850e+05   27247.000000
# 50%          14713.000000  1.595037e+06  144132.000000
# ...

# %%
#statistics for yellow cab

yellow_cab_stats = filtered_yellow_cab.describe()
yellow_cab_stats
# Out:
#         KM_Travelled  Price_Charged   Cost_of_Trip            Age  \
# count  274681.000000  274681.000000  274681.000000  274681.000000
# mean       22.569517     458.181990     297.922004      35.341112
# std        12.234298     288.386166     162.548986      12.578625
# min         1.900000      20.730000      22.800000      18.000000
# 25%        11.990000     226.680000     158.400000      25.000000
# 50%        22.440000     425.060000     295.596000      33.000000
# 75%        32.960000     633.880000     432.432000      42.000000
# max        48.000000    2048.030000     691.200000      65.000000
#
#        Income_(USD/Month)    Population          Users
# count       274681.000000  2.746810e+05  274681.000000
# mean         15045.669817  3.373228e+06  168473.246981
# std           7962.727062  3.439014e+06  100570.558887
# min           2000.000000  2.489680e+05    3643.000000
# 25%           8439.000000  6.712380e+05   80021.000000
# ...

# %%
plot1 = pink_cab.groupby(['Month']).Transaction_ID.count()

# %%
plot1
# Out:
# Month
# 1     4734
# 2     4693
# 3     5724
# 4     5118
# 5     6150
# 6     6371
# 7     7048
# 8     8011
# 9     8518
# 10    9936
# 11    8679
# 12    9729
# Name: Transaction_ID, dtype: int64

# %%
#Transaction frequency by month for Pink cab

plt.figure(figsize=(14,6))
sns.barplot(x = plot1.index, y = plot1.values)
axes.set_title('Pink Cab travel frequency by month')
plt.show()

# %% [markdown]
# The above graph shows that the travel frequency of customers is higher in winter months as compared to other. Also the highest number of transactions go nearby 10000.

# %%
plot2 = yellow_cab.groupby(['Month']).Transaction_ID.count()

# %%
plot2
# Out:
# Month
# 1     17108
# 2     17338
# 3     20754
# 4     19077
# 5     21309
# 6     20568
# 7     23177
# 8     24027
# 9     25377
# 10    29273
# 11    26538
# 12    30135
# Name: Transaction_ID, dtype: int64

# %%
#Transaction frequency by month for Yellow cab

fig, axes = plt.subplots(figsize = (14,6))
sns.barplot(x = plot2.index, y = plot2.values)
axes.set_title('Yellow Cab travel frequency by month')
plt.show()

# %% [markdown]
# The above graph shows that the travel frequency of customers is higher in winter months as compared to other. Also the highest number of transactions go nearby 30000.

# %%
#Comparing both companies' number of transactions

fig, axes = plt.subplots(figsize = (14,6))
axes.plot(plot1.index, plot1.values, color = 'm', linestyle = '-')
axes.plot(plot2.index, plot2.values, color = 'y', linestyle = '--')
plt.xticks(np.arange(min(plot1.index), max(plot1.index)+1, 1.0))
axes.set_title("Number of Transactions monthly for Pink and Yellow Cab")
plt.xlabel("Months")
plt.ylabel("Number of Transactions")
axes.legend(['Pink Cab', 'Yellow Cab'])

# %% [markdown]
# The graph depicts that yellow cab is performing 3x better than the pink cab.

# %%
#Population count by City

plot3 = master_data.groupby(['City']).Population.mean()
plot3
# Out:
# City
# ATLANTA GA         814885.0
# AUSTIN TX          698371.0
# BOSTON MA          248968.0
# CHICAGO IL        1955130.0
# DALLAS TX          942908.0
# DENVER CO          754233.0
# LOS ANGELES CA    1595037.0
# MIAMI FL          1339155.0
# NASHVILLE TN       327225.0
# NEW YORK NY       8405837.0
# ORANGE COUNTY     1030185.0
# PHOENIX AZ         943999.0
# PITTSBURGH PA      542085.0
# SACRAMENTO CA      545776.0
# SAN DIEGO CA       959307.0
# SEATTLE WA         671238.0
# SILICON VALLEY    1177609.0
# TUCSON AZ          631442.0
# WASHINGTON DC      418859.0
# Name: Population, dtype: float64

# %%
#Users of both Cab companies

plot6 = master_data.groupby(['Company']).Users.count()
plot6
# Out:
# Company
# Pink Cab       84711
# Yellow Cab    274681
# Name: Users, dtype: int64

# %%
plot5 = master_data.groupby(['City']).Population.mean()
total_population = sum(plot6.values)
total_population
# Out:
# 359392

# %%
users = [plot6]
users
# Out:
# [Company
#  Pink Cab       84711
#  Yellow Cab    274681
#  Name: Users, dtype: int64]

# %%
total_users = sum(users[0])
total_users
# Out:
# 359392

# %%
#Percentage of users by population

Percent_of_users = master_data.groupby(['Company']).Users.count() / total_users * 100
Percent_of_users
# Out:
# Company
# Pink Cab      23.570642
# Yellow Cab    76.429358
# Name: Users, dtype: float64

# %%
#Pink and Yellow Cab firm users Overview

Percent_of_users.plot.pie(y='Percent_of_users', figsize=(5,5), title = 'Pink and Yellow Cab firm users Overview', autopct='%.0f%%')

plt.show()

# %% [markdown]
# Approximately 3/4th portion of the cab market is acquired by Yellow Cab Company

# %%
#Gender count for both companies

plot7 = pink_cab.groupby(['Gender']).count()
plot8 = yellow_cab.groupby(['Gender']).count()

# %%
plot7
# Out:
#         Transaction_ID  Date_of_Travel  Company   City  KM_Travelled  \
# Gender
# Female           37480           37480    37480  37480         37480
# Male             47231           47231    47231  47231         47231
#
#         Price_Charged  Cost_of_Trip  Month   Year  Customer_ID  Payment_Mode  \
# Gender
# Female          37480         37480  37480  37480        37480         37480
# Male            47231         47231  47231  47231        47231         47231
#
#           Age  Income_(USD/Month)  Population  Users  profit
# Gender
# Female  37480               37480       37480  37480   37480
# Male    47231               47231       47231  47231   47231

# %%
plot8
# Out:
#         Transaction_ID  Date_of_Travel  Company    City  KM_Travelled  \
# Gender
# Female          116000          116000   116000  116000        116000
# Male            158681          158681   158681  158681        158681
#
#         Price_Charged  Cost_of_Trip   Month    Year  Customer_ID  \
# Gender
# Female         116000        116000  116000  116000       116000
# Male           158681        158681  158681  158681       158681
#
#         Payment_Mode     Age  Income_(USD/Month)  Population   Users  profit
# Gender
# Female        116000  116000              116000      116000  116000  116000
# Male          158681  158681              158681      158681  158681  158681

# %%
temp_df = pd.DataFrame({'Pink Cab': [37480, 47231], 'Yellow Cab': [116000, 158681]}, index = ['Female', 'Male'])
temp_df
# Out:
#         Pink Cab  Yellow Cab
# Female     37480      116000
# Male       47231      158681

# %%
#Comparing number of users bifurcating by Gender for bothh companies

temp_df.plot.bar(y = {'Pink Cab', 'Yellow Cab'}, rot = 0, color = {'Pink Cab': 'm', 'Yellow Cab': 'y'})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\2230669208.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   temp_df.plot.bar(y = {'Pink Cab', 'Yellow Cab'}, rot = 0, color = {'Pink Cab': 'm', 'Yellow Cab': 'y'})
# <AxesSubplot:>

# %% [markdown]
# Number of male users are approximately 15% more than female in both the companies

# %%
#Number of users for each city for Pink Cab

plot9 = pink_cab.groupby(['City']).Users.count()
plot9
# Out:
# City
# ATLANTA GA         1762
# AUSTIN TX          1868
# BOSTON MA          5186
# CHICAGO IL         9361
# DALLAS TX          1380
# DENVER CO          1394
# LOS ANGELES CA    19865
# MIAMI FL           2002
# NASHVILLE TN       1841
# NEW YORK NY       13967
# ORANGE COUNTY      1513
# PHOENIX AZ          864
# PITTSBURGH PA       682
# SACRAMENTO CA      1334
# SAN DIEGO CA      10672
# SEATTLE WA         2732
# SILICON VALLEY     3797
# TUCSON AZ           799
# WASHINGTON DC      3692
# Name: Users, dtype: int64

# %%
#Number of users for each city for Yellow Cab

plot10 = yellow_cab.groupby(['City']).Users.count()
plot10
# Out:
# City
# ATLANTA GA         5795
# AUSTIN TX          3028
# BOSTON MA         24506
# CHICAGO IL        47264
# DALLAS TX          5637
# DENVER CO          2431
# LOS ANGELES CA    28168
# MIAMI FL           4452
# NASHVILLE TN       1169
# NEW YORK NY       85918
# ORANGE COUNTY      2469
# PHOENIX AZ         1200
# PITTSBURGH PA       631
# SACRAMENTO CA      1033
# SAN DIEGO CA       9816
# SEATTLE WA         5265
# SILICON VALLEY     4722
# TUCSON AZ          1132
# WASHINGTON DC     40045
# Name: Users, dtype: int64

# %%
df_users = pd.merge(plot9, plot10, on = 'City')
df_users
# Out:
#                 Users_x  Users_y
# City
# ATLANTA GA         1762     5795
# AUSTIN TX          1868     3028
# BOSTON MA          5186    24506
# CHICAGO IL         9361    47264
# DALLAS TX          1380     5637
# DENVER CO          1394     2431
# LOS ANGELES CA    19865    28168
# MIAMI FL           2002     4452
# NASHVILLE TN       1841     1169
# NEW YORK NY       13967    85918
# ORANGE COUNTY      1513     2469
# PHOENIX AZ          864     1200
# PITTSBURGH PA       682      631
# SACRAMENTO CA      1334     1033
# SAN DIEGO CA      10672     9816
# SEATTLE WA         2732     5265
# SILICON VALLEY     3797     4722
# TUCSON AZ           799     1132
# WASHINGTON DC      3692    40045

# %%
fig, axes = plt.subplots(figsize = (18,6))
axes.plot(df_users.index, df_users['Users_x'], color = 'm', linestyle = '-')
axes.plot(df_users.index, df_users['Users_y'], color = 'y', linestyle = '--')
plt.xlabel("City")
plt.xticks(rotation = 45)
plt.ylabel("Users")
axes.set_title("Number of Users in each city for both Companies")
axes.legend(['Pink Cab', 'Yellow Cab'])

# %% [markdown]
# This graph summarizes that yellow cab company has more number of users in most of the cities. Metropolitan cities such as Boston, Chicago, New York, LA , and Washington see a greater hike than other cities.

# %%
plot11 = master_data.groupby(['Company']).Transaction_ID.count()
plot11
# Out:
# Company
# Pink Cab       84711
# Yellow Cab    274681
# Name: Transaction_ID, dtype: int64

# %%
#number of transactions in each company

fig, axes = plt.subplots(figsize = (6,6))
axes.bar(plot11.index, plot11.values, width=0.2)
plt.ylabel('No. of Transactions')
plt.xlabel('Company')
plt.legend
plt.show()

# %% [markdown]
# Yellow Cab Company is performing 3 times better than the Pink Cab Company.

# %%
master_data['profit'] = master_data['Price_Charged'] - master_data['Cost_of_Trip']
master_data
# Out:
#         Transaction_ID Date_of_Travel     Company           City  \
# 0             10000011     2016-08-01    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-06-01    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-06-07  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-02-08  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM_Travelled  Price_Charged  Cost_of_Trip  Month  Year  Customer_ID  \
# 0              30.45         370.95      313.6350      8  2016        29290
# ...

# %%
#Getting companies' average profit

plot12 = master_data.groupby(['Company']).profit.mean()
plot12
# Out:
# Company
# Pink Cab       62.652174
# Yellow Cab    160.259986
# Name: profit, dtype: float64

# %%
#Comparing KM Travelled with Price that was charged for Pink Cab company

fig, axes = plt.subplots(figsize = (14,6))
sns.scatterplot(x = pink_cab['KM_Travelled'], y = pink_cab['Price_Charged'], hue = pink_cab['City'])
plt.ylabel('Price Charged')
plt.xlabel('KM Travelled')
axes.set_title("Pink Cab KM Travelled VS Price Charged")
plt.show()

# %% [markdown]
# For same distance travelled, prices are higher in metropolitan cities as compared to suburb areas.

# %%
#Comparing KM Travelled with Price that was charged for Yellow Cab company

fig, axes = plt.subplots(figsize = (14,6))
sns.scatterplot(x = yellow_cab['KM_Travelled'], y = yellow_cab['Price_Charged'], hue = yellow_cab['City'])
plt.ylabel('Price Charged')
plt.xlabel('KM Travelled')
axes.set_title("Yellow Cab KM Travelled VS Price Charged")
plt.legend
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# For same distance travelled, prices are higher in metropolitan cities as compared to suburb areas.
# Yellow cab charges more in suburban areas too than Pink cab.

# %%
fig, axes = plt.subplots(figsize = (6,6))
axes.bar(plot12.index, plot12.values, width=0.2)
plt.ylabel('Average Profit')
plt.xlabel('Company')
axes.legend
plt.show()

# %% [markdown]
# Average profit for yellow cab company is 2.6 times higher than average profit for pink cab company.

# %%
#Profit for pink cab company for each city

plot13 = pink_cab.groupby(['City']).Users.count()
plot13 = plot13.sort_values(ascending=False)
plot13
# Out:
# City
# LOS ANGELES CA    19865
# NEW YORK NY       13967
# SAN DIEGO CA      10672
# CHICAGO IL         9361
# BOSTON MA          5186
# SILICON VALLEY     3797
# WASHINGTON DC      3692
# SEATTLE WA         2732
# MIAMI FL           2002
# AUSTIN TX          1868
# NASHVILLE TN       1841
# ATLANTA GA         1762
# ORANGE COUNTY      1513
# DENVER CO          1394
# DALLAS TX          1380
# SACRAMENTO CA      1334
# PHOENIX AZ          864
# TUCSON AZ           799
# PITTSBURGH PA       682
# Name: Users, dtype: int64

# %%
plot13.plot.pie(y= 'City', figsize=(10,10), title = 'City wise Profit - Pink Cab', autopct='%.0f%%')

plt.show()

# %% [markdown]
# More than 50% of the Users for Pink Cab are from LA, New York, and San Diego

# %%
plot14 = yellow_cab.groupby(['City']).Users.count()
plot14 = plot14.sort_values(ascending=False)
plot14
# Out:
# City
# NEW YORK NY       85918
# CHICAGO IL        47264
# WASHINGTON DC     40045
# LOS ANGELES CA    28168
# BOSTON MA         24506
# SAN DIEGO CA       9816
# ATLANTA GA         5795
# DALLAS TX          5637
# SEATTLE WA         5265
# SILICON VALLEY     4722
# MIAMI FL           4452
# AUSTIN TX          3028
# ORANGE COUNTY      2469
# DENVER CO          2431
# PHOENIX AZ         1200
# NASHVILLE TN       1169
# TUCSON AZ          1132
# SACRAMENTO CA      1033
# PITTSBURGH PA       631
# Name: Users, dtype: int64

# %%
plot14.plot.pie(y= 'City', figsize=(10,10), title = 'City wise Profit Yellow Cab', autopct='%.0f%%')

plt.show()

# %% [markdown]
# Nearby 3/4th of the market users are from New York, Chicago, Washington and LA.

# %%
plot15 = master_data[master_data.Company=='Pink Cab'].groupby('Year').profit.mean()
plot16 = master_data[master_data.Company=='Yellow Cab'].groupby('Year').profit.mean()

# %%
fig, axes = plt.subplots(figsize = (6,6))
axes.bar(plot15.index-0.2, plot15.values, width=0.4, color = 'm')
axes.bar(plot16.index+0.2, plot16.values, width=0.4, color = 'y')
plt.ylabel('Average Profit($)')
plt.xlabel('Year')
plt.xticks(np.arange(min(plot16.index), max(plot16.index)+1, 1.0))
axes.set_title('Profit by year for both companies')
axes.legend(['Pink Cab', 'Yellow Cab'])
plt.show()

# %% [markdown]
# Average profit for both the companies is declining from the year 2016 to 2018. Average profit of the Yellow company is nearby 2.5 times higher in all the years than Pink cab.

# %%
plot17 = pink_cab.groupby(['City']).profit.mean()
plot17 = plot17.sort_values(ascending=False)
plot17
# Out:
# City
# NEW YORK NY       108.217540
# SILICON VALLEY     89.610358
# MIAMI FL           81.069526
# AUSTIN TX          78.932168
# TUCSON AZ          74.204725
# ORANGE COUNTY      67.412976
# SAN DIEGO CA       59.772280
# LOS ANGELES CA     56.669120
# ATLANTA GA         54.511961
# WASHINGTON DC      52.482761
# BOSTON MA          50.520960
# SACRAMENTO CA      41.472273
# SEATTLE WA         41.281601
# PHOENIX AZ         41.199530
# NASHVILLE TN       34.918269
# CHICAGO IL         34.047910
# DENVER CO          29.114016
# PITTSBURGH PA      25.084660
# DALLAS TX          17.920371
# Name: profit, dtype: float64

# %%
plot17.plot.pie(y= 'City', figsize=(10,10), title = 'Profit by City- Pink Cab', autopct='%.0f%%')
plt.show()

# %%
plot18 = master_data[master_data.Company=='Yellow Cab'].groupby(['City']).profit.mean()
plot18 = plot18.sort_values(ascending=False)
plot18
# Out:
# City
# NEW YORK NY       307.864252
# SILICON VALLEY    206.788383
# DALLAS TX         195.849415
# DENVER CO         146.853175
# ORANGE COUNTY     143.785355
# MIAMI FL          133.872429
# PHOENIX AZ        131.120407
# ATLANTA GA        128.797723
# AUSTIN TX         125.249582
# LOS ANGELES CA    116.656368
# PITTSBURGH PA     107.857716
# SAN DIEGO CA       96.706775
# SEATTLE WA         93.428968
# WASHINGTON DC      82.384912
# NASHVILLE TN       72.923597
# TUCSON AZ          71.529258
# CHICAGO IL         64.924486
# BOSTON MA          61.483619
# SACRAMENTO CA      60.021471
# Name: profit, dtype: float64

# %%
plot18.plot.pie(y= 'City', figsize=(10,10), title = 'Profit by City - Yellow Cab', autopct='%.0f%%')
plt.show()

# %%
df_profit = pd.merge(plot17, plot18, on = 'City')
df_profit
# Out:
#                   profit_x    profit_y
# City
# NEW YORK NY     108.217540  307.864252
# SILICON VALLEY   89.610358  206.788383
# MIAMI FL         81.069526  133.872429
# AUSTIN TX        78.932168  125.249582
# TUCSON AZ        74.204725   71.529258
# ORANGE COUNTY    67.412976  143.785355
# SAN DIEGO CA     59.772280   96.706775
# LOS ANGELES CA   56.669120  116.656368
# ATLANTA GA       54.511961  128.797723
# WASHINGTON DC    52.482761   82.384912
# BOSTON MA        50.520960   61.483619
# SACRAMENTO CA    41.472273   60.021471
# SEATTLE WA       41.281601   93.428968
# PHOENIX AZ       41.199530  131.120407
# NASHVILLE TN     34.918269   72.923597
# CHICAGO IL       34.047910   64.924486
# DENVER CO        29.114016  146.853175
# PITTSBURGH PA    25.084660  107.857716
# DALLAS TX        17.920371  195.849415

# %%
fig, axes = plt.subplots(figsize = (15,6))
x = np.arange(len(df_profit.index))
axes.plot(df_profit.index, df_profit['profit_x'], color = 'm')
axes.plot(df_profit.index, df_profit['profit_y'], color = 'y')
plt.ylabel('Average Profit($)')
plt.xticks(rotation = 45)
axes.set_title('Average profit in all cities for both companies')
axes.legend(['Pink Cab', 'Yellow Cab'])
plt.show()

# %% [markdown]
# Average profit for pink cab is the highest in New York of a little more than $ 100.  And the least in Dallas, TX or nearby $ 10. Average profit for both companies is similar in cities like Tucson & Boston. Whereas, average profit for Yellow cab is highest in NYC of approximately $ 300. Yellow cab is also performing better in cities like Denver and Dallas in which Pink cab could not perform well.

# %%
ageGroup_Young  = pink_cab[(pink_cab ["Age"] >= 18) & (pink_cab ["Age"] < 25)].count()
ageGroup_Middle = pink_cab[(pink_cab ["Age"] >= 25) & (pink_cab ["Age"] < 40)].count()
ageGroup_Old    = pink_cab[(pink_cab ["Age"] >= 40) & (master_data ["Age"] <= 65)].count()

dict = {"Young" : ageGroup_Young, "Middle aged" : ageGroup_Middle, "Old aged" : ageGroup_Old}
plot20 = pd.DataFrame(dict).T
plot20 = pd.DataFrame(plot20["Users"])
plot20
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\165983532.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ageGroup_Old    = pink_cab[(pink_cab ["Age"] >= 40) & (master_data ["Age"] <= 65)].count()
#              Users
# Young        19306
# Middle aged  40069
# Old aged     25336

# %%
AgeGroup_Young  = yellow_cab[(yellow_cab ["Age"] >= 18) & (yellow_cab ["Age"] < 25)].count()
AgeGroup_Middle = yellow_cab[(yellow_cab ["Age"] >= 25) & (yellow_cab ["Age"] < 40)].count()
AgeGroup_Old    = yellow_cab[(yellow_cab ["Age"] >= 40) & (yellow_cab ["Age"] <= 65)].count()

dict = {"Young" : AgeGroup_Young, "Middle aged" : AgeGroup_Middle, "Old aged" : AgeGroup_Old}
plot21 = pd.DataFrame(dict).T
plot21 = pd.DataFrame(plot21["Users"])
plot21
# Out:
#               Users
# Young         62065
# Middle aged  130162
# Old aged      82454

# %%
df_age = pd.merge(plot20, plot21, on = plot20.index)
df_age.rename(columns = {'Users_x' : 'Pink Cab', 'Users_y' : 'Yellow Cab'}, inplace = True)
df_age = df_age.set_index('key_0')
df_age
# Out:
#              Pink Cab  Yellow Cab
# key_0
# Young           19306       62065
# Middle aged     40069      130162
# Old aged        25336       82454

# %%
df_age.plot.bar(y = {'Pink Cab', 'Yellow Cab'}, rot = 0, color = {'Pink Cab': 'm', 'Yellow Cab': 'y'}, xlabel = 'Age Groups', ylabel = 'Users')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\3164624200.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_age.plot.bar(y = {'Pink Cab', 'Yellow Cab'}, rot = 0, color = {'Pink Cab': 'm', 'Yellow Cab': 'y'}, xlabel = 'Age Groups', ylabel = 'Users')
# <AxesSubplot:xlabel='Age Groups', ylabel='Users'>

# %% [markdown]
# Middle aged people are more likely to book a cab in both the companies. But yellow cab is definitely having higher number of users than pink cab.

# %%
#Correlation chart for numerical values

plot19 = master_data[['KM_Travelled', 'Price_Charged', 'Cost_of_Trip', 'Income_(USD/Month)', 'profit']]
plot19.corr()
# Out:
#                     KM_Travelled  Price_Charged  Cost_of_Trip  \
# KM_Travelled            1.000000       0.835753      0.981848
# Price_Charged           0.835753       1.000000      0.859812
# Cost_of_Trip            0.981848       0.859812      1.000000
# Income_(USD/Month)     -0.000544       0.003228     -0.000633
# profit                  0.462768       0.864154      0.486056
#
#                     Income_(USD/Month)    profit
# KM_Travelled                 -0.000544  0.462768
# Price_Charged                 0.003228  0.864154
# Cost_of_Trip                 -0.000633  0.486056
# Income_(USD/Month)            1.000000  0.006148
# profit                        0.006148  1.000000

# %%
#Heatmap for core values

plt.figure(figsize=(20,10))
sns.heatmap(plot19.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Cost of Trip is highly related to KMs Travelled. Profit is partially proportionated to KM Travelled.
